# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ply
import seaborn as sns

import os, json, math, time

from yelpapi import YelpAPI

from tqdm.notebook import tqdm_notebook

# %%
with open('/Users/laura/.secret/yelp_api.json', 'r') as f: 
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['Client-id', 'API Key'])

# %%
yelp = YelpAPI(login['API Key'], timeout_s=5.0)

# %%
location = 'Sioux Falls, SD' 
term = 'Ice Cream'

# %%
location.split(',')[0]
# Out:
# 'Sioux Falls'

# %%
ice_cream = yelp.search_query(term = term, location = location)

# %%
type(ice_cream)
# Out:
# dict

# %%
ice_cream.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
ice_cream_1 = pd.DataFrame(ice_cream['businesses'])

# %%
ice_cream_1.head()
# Out:
#                        id                                 alias  \
# 0  pVFT-7edP4yQAfPM6cIurw   parlour-ice-cream-house-sioux-falls
# 1  Ji7lxOTT_hS3pZIBhshf3w  stensland-family-farms-sioux-falls-6
# 2  DC32sJJK3CPrXw_UMQk-xw        b-and-g-milkyway-sioux-falls-2
# 3  XV3rgk0pUhwDxo5iuYftdw             ch-patisserie-sioux-falls
# 4  io8QnKYq-tk1-nbqVY45aw               polar-bites-sioux-falls
#
#                       name                                          image_url  \
# 0  Parlour Ice Cream House  https://s3-media2.fl.yelpcdn.com/bphoto/36hYav...
# 1   Stensland Family Farms  https://s3-media1.fl.yelpcdn.com/bphoto/Eb82tc...
# 2             B&G Milkyway  https://s3-media1.fl.yelpcdn.com/bphoto/c3Fffn...
# 3            Ch Patisserie  https://s3-media1.fl.yelpcdn.com/bphoto/W0DWc3...
# 4              Polar Bites  https://s3-media2.fl.yelpcdn.com/bphoto/-30VxZ...
#
#    is_closed                                                url  review_count  \
# ...

# %%
ice_cream['total']
# Out:
# 116

# %%
ice_cream_offset = yelp.search_query(location = location, term= term, offset = 20)

# %%
ice_cream_2 = pd.DataFrame(ice_cream_offset['businesses'])

# %%
ice_cream_2.head()
# Out:
#                        id                                            alias  \
# 0  UZbA3v7ikLzJ2IhcBTuPxQ                  the-goat-bar-and-grill-hartford
# 1  O_T2tpOmewJfd9tlOVWwGQ  bread-and-circus-sandwich-kitchen-sioux-falls-5
# 2  eqt3ziZDPNwYKkMOX4K4sw                   rolln-pin-catering-sioux-falls
# 3  XRfePMunbJyVeBMvN-5uPQ       dairy-queen-grill-and-chill-sioux-falls-10
# 4  zIyZSt1K48WJ8MjVqOJlxw         papa-woodys-wood-fired-pizza-sioux-falls
#
#                               name  \
# 0           The Goat Bar and Grill
# 1  Bread & Circus Sandwich Kitchen
# 2              Roll'n Pin Catering
# 3        Dairy Queen Grill & Chill
# 4    Papa Woody's Wood Fired Pizza
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/alGQMX...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/NvU_V6...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/-Nv04g...      False
# ...

# %%
ice_cream_combined = pd.concat([ice_cream_1, ice_cream_2], ignore_index=True)
ice_cream_combined
# Out:
#                         id                                            alias  \
# 0   pVFT-7edP4yQAfPM6cIurw              parlour-ice-cream-house-sioux-falls
# 1   Ji7lxOTT_hS3pZIBhshf3w             stensland-family-farms-sioux-falls-6
# 2   DC32sJJK3CPrXw_UMQk-xw                   b-and-g-milkyway-sioux-falls-2
# 3   XV3rgk0pUhwDxo5iuYftdw                        ch-patisserie-sioux-falls
# 4   io8QnKYq-tk1-nbqVY45aw                          polar-bites-sioux-falls
# 5   ll_CYtEUmYVBN8yPd5AtSw                   b-and-g-milkyway-sioux-falls-5
# 6   iJ9IDRj9pZMCVpdzVXLQww                   b-and-g-milkyway-sioux-falls-4
# 7   psMo2bT78JF1GVL52hiQzA                          boki-gelato-sioux-falls
# 8   mHoTpJs-tUeRlgsz6iaauw                  cold-stone-creamery-sioux-falls
# 9   WEytBz1B0UR2uRuEIGA5qw                         cherry-berry-sioux-falls
# 10  2dPpldWRKk_V3Qdqyv__iA           crumbl-cookies-41st-street-sioux-falls
# ...

# %%
ice_cream_combined.to_json(orient='records')
# Out:
# '[{"id":"pVFT-7edP4yQAfPM6cIurw","alias":"parlour-ice-cream-house-sioux-falls","name":"Parlour Ice Cream House","image_url":"https:\\/\\/s3-media2.fl.yelpcdn.com\\/bphoto\\/36hYav8g6jZgprzlU_eGVQ\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/parlour-ice-cream-house-sioux-falls?adjust_creative=6STl72FfMy0OdTs4H8mRbA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6STl72FfMy0OdTs4H8mRbA","review_count":25,"categories":[{"alias":"icecream","title":"Ice Cream & Frozen Yogurt"}],"rating":4.5,"coordinates":{"latitude":43.54372,"longitude":-96.72793},"transactions":[],"location":{"address1":"340 S Main Ave","address2":"","address3":null,"city":"Sioux Falls","zip_code":"57104","country":"US","state":"SD","display_address":["340 S Main Ave","Sioux Falls, SD 57104"]},"phone":"","display_phone":"","distance":524.6112612252,"price":null},{"id":"Ji7lxOTT_hS3pZIBhshf3w","alias":"stensland-family-farms-sioux-falls-6","name":"Stensland Family Farms","image_
# ...
